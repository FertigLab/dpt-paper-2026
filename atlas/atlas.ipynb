# %%
library(Seurat)
# Out:
# Attaching SeuratObject
#
# Attaching sp

# %%
library(SeuratDisk)
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %%
atlas <- readRDS('scAtlas.rds')

# %%
SaveH5Seurat(atlas, filename = "scAtlas.rds.h5Seurat", verbose = TRUE, overwrite = FALSE)
# Out:
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for RNA
#
# Adding data for RNA
#
# Adding scale.data for RNA
#
# Adding variable features for RNA
#
# Adding feature-level metadata for RNA
#
# Adding cell embeddings for pca
#
# Adding loadings for pca
#
# No projected loadings for pca
#
# Adding standard deviations for pca
#
# No JackStraw data for pca
#
# Adding cell embeddings for harmony
#
# Adding loadings for harmony
#
# Adding projected loadings for harmony
#
# Adding standard deviations for harmony
#
# No JackStraw data for harmony
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap

# %%
Convert("scAtlas.rds.h5Seurat", dest = "h5ad", raw.slot = 'counts')
# Out:
# Validating h5Seurat file
#
# Adding scale.data from RNA as X
#
# Transfering meta.features to var
#
# Adding data from RNA as raw
#
# Transfering meta.features to raw/var
#
# Transfering meta.data to obs
#
# Adding dimensional reduction information for harmony

# %%
h5 <- hdf5r::h5file('scAtlas.rds.h5ad')

# %%
h5$ls()
# Out:
#   name link.type obj_type num_attrs group.nlinks group.mounted dataset.rank
# 1 X    0         5        0         NA           NA             2
# 2 obs  0         2        4         15            0            NA
# 3 obsm 0         2        0          3            0            NA
# 4 raw  0         2        0          2            0            NA
# 5 var  0         2        4          6            0            NA
# 6 varm 0         2        0          2            0            NA
#   dataset.dims  dataset.maxdims dataset.type_class dataset.space_class
# 1 5000 x 726107 Inf x Inf        1                  1
# 2 NA            NA              NA                 NA
# 3 NA            NA              NA                 NA
# 4 NA            NA              NA                 NA
# 5 NA            NA              NA                 NA
# 6 NA            NA              NA                 NA
#   committed_type
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
unique(h5[['obs']][['DiseaseState']][1:700000])
# Out:
# [1] 2 3 1 0

# %%
h5[['raw']][['X']][['data']][1:100]
# Out:
#   [1] 1.615869 2.572366 1.615869 1.615869 2.572366 1.615869 2.572366 1.615869
#   [9] 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869
#  [17] 1.615869 1.615869 1.615869 2.204367 2.204367 1.615869 1.615869 1.615869
#  [25] 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869
#  [33] 1.615869 1.615869 2.840775 1.615869 2.204367 3.504297 2.204367 1.615869
#  [41] 1.615869 1.615869 2.572366 3.052174 1.615869 1.615869 1.615869 2.204367
#  [49] 2.204367 1.615869 1.615869 1.615869 1.615869 2.204367 1.615869 2.840775
#  [57] 4.898321 0.000000 1.615869 1.615869 2.204367 3.618734 2.572366 2.572366
#  [65] 1.615869 1.615869 1.615869 1.615869 4.402383 1.615869 1.615869 2.572366
#  [73] 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 1.615869 2.572366
#  [81] 1.615869 1.615869 1.615869 2.840775 1.615869 1.615869 1.615869 1.615869
#  [89] 1.615869 1.615869 1.615869 2.572366 2.572366 1.615869 1.615869 1.615869
# ...
