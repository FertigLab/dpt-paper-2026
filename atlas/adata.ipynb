# %%
import anndata as ad

# %%
adata = ad.read_h5ad('scAtlas.rds.h5ad')

# %%
adata.obs
# Out:
#                         nCount_RNA  nFeature_RNA  percent.mt  seurat_clusters  \
# AAACATACTCGTTT-1_1          2480.0           962   12.661290                4
# AAACCGTGGGTAGG-1_1           690.0           338    2.173913                3
# AAAGCAGACTGAGT-1_1          1670.0           623    2.155689                3
# AAAGGCCTGCTCCT-1_1         14476.0          2799    1.499033                3
# AAATACTGTGGATC-1_1         14087.0          2557    0.305246                3
# ...                            ...           ...         ...              ...
# TTTGGTTTCGGCTTCT-1_250      4256.0          1882    1.785714                4
# TTTGTTGCAAATGAAC-1_250       640.0           492    1.875000                4
# TTTGTTGCAGAGTCAG-1_250       669.0           250    0.000000                9
# TTTGTTGCATTGAAGA-1_250     21450.0          2451    0.079254                9
# TTTGTTGGTTCTGACA-1_250     47485.0          4685    0.035801                9
#
#                         Count  \
# ...

# %%
adata.obs_keys
# Out:
# <bound method AnnData.obs_keys of AnnData object with n_obs × n_vars = 726107 × 5000
#     obs: 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'seurat_clusters', 'Count', 'Study..Citation..PMID.', 'GSE.SRA..Study.', 'Name', 'If.metastatic..location', 'Clusters', 'Treatment', 'DiseaseState', 'TreatmentType'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'HARMONY', 'PCs'>

# %%
adata.var_names
# Out:
# Index(['SAMD11', 'HES4', 'ISG15', 'TNFRSF18', 'TNFRSF4', 'MXRA8', 'VWA1',
#        'MMP23B', 'TMEM52', 'GABRD',
#        ...
#        'AC010737.1', 'RPS4Y2', 'MT-ATP8', 'MT-ND4L', 'MT-ND6', 'AC233755.2',
#        'AC233755.1', 'AC136616.2', 'AC141272.1', 'AC007325.2'],
#       dtype='object', length=5000)

# %%
import numpy as np

# %%
np.unique(adata.obs['Clusters'])
# Out:
# array(['ACINAR', 'B CELLS', 'CYCLING DUCTAL', 'CYCLING TNK',
#        'CYCLING. MYELOID', 'DUCTAL', 'ENDOCRINE', 'ENDOTHELIAL',
#        'FIBROBLASTS', 'MAST', 'MYELOID', 'PERICYTES', 'PLASMA', 'TNK'],
#       dtype=object)

# %%
len(adata.obs['Clusters'])
# Out:
# 726107
